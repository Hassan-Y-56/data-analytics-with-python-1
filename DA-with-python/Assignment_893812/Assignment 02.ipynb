# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here

name = input("Enter your name: ")
Current_salary = int(input("Enter your current salary: "))
yos = int(input("Enter your years of service: "))

if yos >= 5:
    new_salary = Current_salary * 1.05
    print(f"Congratulations {name}! You are eligible for a 5% salary increase.")
    print(f"Your new salary is: {new_salary}")
else:
    print(f"Sorry {name}, you are not eligible for a salary increase at this time.")
# Out:
# Congratulations hassab! You are eligible for a 5% salary increase.
# Your new salary is: 105000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here

name = input("Enter your name: ")
age = int(input("Enter your age: "))

if age > 17:
    print(f"hello {name}, you are eligible to vote.")
else:
    print(f"hello {name}, you are not eligible to vote.")
# Out:
# hello saqib, you are not eligible to vote.

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here

num = int(input("Enter a number: "))

if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")
# Out:
# 7 is an odd number.

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here

num = int(input("Enter a number: "))

if num % 7 == 0:
    print(f"{num} is divisible by 7.")
else:
    print(f"{num} is not divisible by 7.")
# Out:
# 34 is not divisible by 7.

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here

num = int(input("Enter a number: "))

if num % 5 == 0:
    print(f"{num}, is a multiple of 5.")
else:
    print(f"{num}, is not a multiple of 5.")
# Out:
# 76, is not a multiple of 5.

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here

num = (input("Enter a number: "))

print(f"The last digit of number is {num[-1]}")
# Out:
# The last digit of number is 7

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 

length = int(input("Enter the length of the shape: "))
breadth = int(input("Enter the breadth of the shape: "))

if length == breadth:
    print(f"The shape is a square.")
else:
    print(f"The shape is a rectangle.")
# Out:
# The shape is a rectangle.

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

if num1 > num2:
    print(f"{num1} is greater.")
else:
    print(f"{num2} is greater.")
# Out:
# 8 is greater.

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
product_a = 150
product_b = 100
quantity_a = int(input("Enter the quantity of product A: "))
quantity_b = int(input("Enter the quantity of product B: "))

total_bill = quantity_a * product_a + quantity_b * product_b
print(f"Your total bill amount is: {total_bill}")
if total_bill > 1000:
    final_amount = total_bill * 0.9
    print(f"You have received 10% discount. Your final bill amount is: {final_amount}")
else:
    print(f"Your final bill amount is: {total_bill}")
# Out:
# Your total bill amount is: 1150
# You have received 10% discount. Your final bill amount is: 1035.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
marks = int(input("Enter your marks: "))

if marks >= 80:
    print("Grade: A")
elif marks >= 60 and marks < 80:
    print("Grade: B")
elif marks >= 50 and marks < 60:
    print("Grade: C")
elif marks >= 45 and marks < 50:
    print("Grade: D")
elif marks >= 25 and marks < 45:
    print("Grade: E")
else:
    print("Grade: F")
# Out:
# Grade: B

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here

total_classes = int(input("Enter the total number of classes held: "))
attended_classes = int(input("Enter the total number of classes attended: "))

class_percentage = (attended_classes / total_classes) * 100
print(f"Your attendance percentage is: {class_percentage}%")
if class_percentage < 75:
    print("You are not allowed to sit in the exam.")
else:
    print("You are allowed to sit in the exam.")
# Out:
# Your attendance percentage is: 75.0%
# You are allowed to sit in the exam.

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here

year = int(input("Enter a year: "))

if (year % 4 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
units_used = int(input("Enter the number of units used: "))
if units_used <= 100:
    bill_amount = units_used * 0
    print(f"Your bill amount is: {bill_amount}")
elif units_used >100 and units_used <= 200:
    bill_amount = (units_used * 5)
    print(f"Your bill amount is: {bill_amount}")
else:
    bill_amount = (units_used * 10)
    print(f"Your bill amount is: {bill_amount}")
# Out:
# Your bill amount is: 3000

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here

person1 = int(input("Enter the age of person 1: "))
person2 = int(input("Enter the age of person 2: "))
person3 = int(input("Enter the age of person 3: "))

if person1 > person2 and person2 > person3:
    print(f"Person 1 is the oldest and Person 3 is the youngest.")
elif person2 > person1 and person1 > person3:
    print(f"Person 2 is the oldest and Person 3 is the youngest.")
elif person3 > person1 and person1 > person2:
    print(f"Person 3 is the oldest and Person 2 is the youngest.")
elif person1 > person3 and person3 > person2:
    print(f"Person 1 is the oldest and Person 2 is the youngest.")
elif person2 > person3 and person3 > person1:
    print(f"Person 2 is the oldest and Person 1 is the youngest.")
else:
    print(f"Person 3 is the oldest and Person 1 is the youngest.")
# Out:
# Person 2 is the oldest and Person 1 is the youngest.
