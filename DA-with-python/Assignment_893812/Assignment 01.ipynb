# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Write your code here 

print ("Muhammad Hassan \nMuhammad yousuf \nD.O.B: 05-03-1991")
# Out:
# Muhammad Hassan
# Muhammad yousuf
# D.O.B: 05-03-1991

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here

Name = "Muhammad Hassan"
Father_name = "Muhammad Yousuf"
Qualification = "MBA"
print (Name)
print (Father_name)
print(Qualification)
# Out:
# Muhammad Hassan
# Muhammad Yousuf
# MBA

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here

a = int(input("Enter first value"))
b = int(input("Enter Second value"))
print("A plus b =",a+b)
print("A minus b =",a-b)
print("A multiply b =",a*b)
print("A divide b =",a/b)
print("A remainder b =",a%b)
print("A Equals to b =",a==b)
print("A greater than b =",a>b)
print("A less than b =",a<b)
print("A less than equals to b =",a<=b)
print("A greater than equals to b =",a>=b)
# Out:
# A plus b = 8
# A minus b = 2
# A multiply b = 15
# A divide b = 1.6666666666666667
# A remainder b = 2
# A Equals to b = False
# A greater than b = True
# A less than b = False
# A less than equals to b = False
# A greater than equals to b = True

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here

English = 68
Islamiat = 84
Maths = 96
Total_Marks = 300
print (((English+Islamiat+Maths)/Total_Marks)*100)
# Out:
# 82.66666666666667

# %% [markdown]
# 5. Take the values of two variables `a` and `b`, then swap their values without using a third variable and print the result before and after swapping

# %%
# Write your code here

a = int(input("Enter value of a"))
b = int(input("Enter value of b"))
print("Before swapping: a =", a, ", b =", b)
a, b = b, a
print("After swapping: a =", a, ", b =", b)
# Out:
# Before swapping: a = 5 , b = 7
# After swapping: a = 7 , b = 5

# %% [markdown]
# 6. Take the radius of a circle from a variable and calculate its Area and Circumference (use `pi = 3.14159`)

# %%
# Write your code here

r = int(input("Enter radius of circle"))
pi = 3.14159
Area_of_circle = (pi*(r*r))
Circumference_of_circle = (2*pi*r)
print(Area_of_circle)
print(Circumference_of_circle)
# Out:
# 113.09724
# 37.699079999999995

# %% [markdown]
# 7. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
# Write your code here

item_price = int(input("Enter price of item"))
Discount_percentage = int(input("Enter discount percentage"))
Discount = ((item_price*Discount_percentage)/100)
print ("item price =", item_price)
print ("Discount on item =", Discount)
print ("Final price = ", item_price-Discount)
# Out:
# item price = 500
# Discount on item = 50.0
# Final price =  450.0
